# %% [markdown]
# #Pandas test
# La felicidad es un aspecto muy importante de nuestra sociedad.
#
# Como individuos, intentamos buscar la felicidad durante toda nuestra vida.
#
# Pero en una visión más amplia, una sociedad feliz también parece correlacionarse con un mayor compromiso con los Objetivos de Desarrollo Sostenible(ODS).
#
# Como se puede leer en el Informe Mundial sobre la Felicidad 2020(World Happiness Report) "A medida que los países se enriquecen, el bienestar de sus ciudadanos se estanca a menos que el crecimiento económico sea más sostenible, por ejemplo, abordando la desigualdad y mejorando la calidad del medio ambiente."

# %% [markdown]
# ![Screenshot 2021-08-19 at 15.40.44.png](data:image/png;base64,...)

# %% [markdown]
# Para esta prueba, utilizarás los datos del Informe Mundial de la Felicidad 2015 y 2019 de Kaggle: https://www.kaggle.com/unsdsn/world-happiness?select=2019.csv
#
# **Consejo:** Si las cosas se ponen difíciles, no dudes en pedir ayuda a Google. Un pequeño secreto: la programación es básicamente un 10% de habilidad y un 90% de saber buscar en Google la forma de salir de los problemas. Pero no se lo digas a nadie ;)
#
#
# ¡Vamos a sumergirnos en los datos!

# %% [markdown]
# ####1. Load the 2 datasets

# %% [markdown]
# ####2. Remove 'Dystopia residual' from 2015 dataset

# %% [markdown]
# ####3. Add column ‘Year’ to both 2015 and 2019 dataset

# %% [markdown]
# ####4. Create a new column Region and assign the regions from the 2015 dataset to the right countries in the 2019 dataset

# %% [markdown]
# ####5. Bubble chart of Freedom Vs Trust where the size of the bubble is the GDP per Capita for 2019

# %% [markdown]
# ####6. Bubble chart of Family Vs Health where the size is the happiness score of 2015

# %% [markdown]
# ####7. List the 3 variables that have the strongest correlation with the Happiness score (use Pearson Correlation)
